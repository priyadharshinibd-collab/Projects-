# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadharshinibd-collab/Projects-/blob/main/task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **identify patterns,trends,or anomalies in the data**

# %%
print("Interpreting the generated plots:")

print("\nDistribution of Age:")
print("The histogram shows a distribution of age that is somewhat right-skewed, with a peak around 20-30 years old. There is a tail extending towards older ages. The KDE line confirms this general shape. This suggests a majority of passengers were young adults.")

print("\nDistribution of Fare:")
print("The Fare distribution is highly right-skewed, with most fares being relatively low and a few outliers with very high fares. This indicates a wide range of economic backgrounds among passengers, with a concentration in lower fare classes.")

print("\nDistribution of Pclass:")
print("The count plot for Pclass shows that the majority of passengers were in Pclass 3, followed by Pclass 1, and then Pclass 2. This suggests that the ship had more third-class accommodations.")

print("\nDistribution of Sex:")
print("The count plot for Sex clearly shows that there were significantly more male passengers than female passengers.")

print("\nDistribution of Embarked:")
print("The count plot for Embarked indicates that most passengers embarked from 'S' (Southampton), followed by 'C' (Cherbourg), and then 'Q' (Queenstown).")

print("\nSurvival by Pclass:")
print("The stacked count plot shows a clear relationship between Pclass and survival. Passengers in Pclass 1 had a much higher survival rate than those in Pclass 2 or 3. Pclass 3 had the lowest survival rate.")

print("\nSurvival by Sex:")
print("The stacked count plot for Sex reveals a very strong relationship with survival. A significantly higher proportion of female passengers survived compared to male passengers. This is a very prominent pattern.")

print("\nSurvival by Embarked:")
print("The stacked count plot for Embarked shows some variation in survival rates by embarkation point, although the difference is less pronounced than for Pclass or Sex. Passengers from 'C' appear to have a slightly higher survival rate.")

print("\nSurvival by Age:")
print("The violin plot shows the distribution of age for those who survived and those who did not. The distribution for those who did not survive is slightly skewed towards younger adults, while the distribution for survivors is more spread out, including a notable number of children and older adults who survived.")

print("\nSurvival by Fare:")
print("The box plot for Survival by Fare indicates that passengers who paid higher fares had a higher chance of survival. The median fare for survivors is significantly higher than for those who did not survive, and there are many outliers with high fares in the survived group.")

print("\nSurvival by SibSp:")
print("The count plot for Survival by SibSp suggests that passengers with a small number of siblings or spouses (SibSp 1 or 2) had a higher survival rate than those with no siblings/spouses or a large number. Passengers with a large number of SibSp had a very low survival rate.")

print("\nSurvival by Parch:")
print("The count plot for Survival by Parch shows a similar pattern to SibSp. Passengers with a small number of parents or children (Parch 1, 2, or 3) had a higher survival rate than those with no parents/children or a large number.")
# Out:
# Interpreting the generated plots:
#
# Distribution of Age:
# The histogram shows a distribution of age that is somewhat right-skewed, with a peak around 20-30 years old. There is a tail extending towards older ages. The KDE line confirms this general shape. This suggests a majority of passengers were young adults.
#
# Distribution of Fare:
# The Fare distribution is highly right-skewed, with most fares being relatively low and a few outliers with very high fares. This indicates a wide range of economic backgrounds among passengers, with a concentration in lower fare classes.
#
# Distribution of Pclass:
# The count plot for Pclass shows that the majority of passengers were in Pclass 3, followed by Pclass 1, and then Pclass 2. This suggests that the ship had more third-class accommodations.
#
# Distribution of Sex:
# The count plot for Sex clearly shows that there were significantly more male passengers than female passengers.
#
# Distribution of Embarked:
# ...

# %% [markdown]
# ## Explore Feature Relationships
#
# ### Subtask:
# Visualize the relationships between numerical features using a pairplot and a correlation heatmap.

# %% [markdown]
# **Reasoning**:
# Review and refine the generated visualizations for better clarity and presentation by adding more descriptive titles, axis labels, and adjusting font sizes for improved readability.

# %%
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(18, 24))
axes = axes.flatten()

# Distribution of Age
sns.histplot(data=df, x='Age', ax=axes[0], kde=True, color='skyblue')
axes[0].set_title('Distribution of Passenger Age', fontsize=14)
axes[0].set_xlabel('Age', fontsize=12)
axes[0].set_ylabel('Frequency', fontsize=12)

# Distribution of Fare
sns.histplot(data=df, x='Fare', ax=axes[1], kde=True, color='lightcoral')
axes[1].set_title('Distribution of Passenger Fare', fontsize=14)
axes[1].set_xlabel('Fare', fontsize=12)
axes[1].set_ylabel('Frequency', fontsize=12)

# Distribution of Pclass
sns.countplot(data=df, x='Pclass', hue='Pclass', ax=axes[2], palette='viridis', legend=False) # Explicitly set hue and hide legend
axes[2].set_title('Distribution of Passenger Class', fontsize=14)
axes[2].set_xlabel('Passenger Class', fontsize=12)
axes[2].set_ylabel('Count', fontsize=12)

# Distribution of Sex
sns.countplot(data=df, x='Sex', hue='Sex', ax=axes[3], palette='plasma', legend=False) # Explicitly set hue and hide legend
axes[3].set_title('Distribution of Passenger Sex', fontsize=14)
axes[3].set_xlabel('Sex', fontsize=12)
axes[3].set_ylabel('Count', fontsize=12)

# Distribution of Embarked
sns.countplot(data=df.dropna(subset=['Embarked']), x='Embarked', hue='Embarked', ax=axes[4], palette='mako', legend=False) # Explicitly set hue and hide legend
axes[4].set_title('Distribution of Embarkation Point', fontsize=14)
axes[4].set_xlabel('Embarkation Point', fontsize=12)
axes[4].set_ylabel('Count', fontsize=12)

# Survival by Pclass
sns.countplot(data=df, x='Pclass', hue='Survived', ax=axes[5], palette='viridis')
axes[5].set_title('Survival Count by Passenger Class', fontsize=14)
axes[5].set_xlabel('Passenger Class', fontsize=12)
axes[5].set_ylabel('Count', fontsize=12)
axes[5].legend(title='Survived', loc='upper right')

# Survival by Sex
sns.countplot(data=df, x='Sex', hue='Survived', ax=axes[6], palette='plasma')
axes[6].set_title('Survival Count by Sex', fontsize=14)
axes[6].set_xlabel('Sex', fontsize=12)
axes[6].set_ylabel('Count', fontsize=12)
axes[6].legend(title='Survived', loc='upper right')

# Survival by Embarked
sns.countplot(data=df.dropna(subset=['Embarked']), x='Embarked', hue='Survived', ax=axes[7], palette='mako')
axes[7].set_title('Survival Count by Embarkation Point', fontsize=14)
axes[7].set_xlabel('Embarkation Point', fontsize=12)
axes[7].set_ylabel('Count', fontsize=12)
axes[7].legend(title='Survived', loc='upper right')

# Survival by Age
sns.violinplot(data=df.dropna(subset=['Age', 'Survived']), x='Survived', y='Age', ax=axes[8], hue='Survived', palette='rocket', legend=False) # Explicitly set hue and hide legend
axes[8].set_title('Survival by Age Distribution', fontsize=14)
axes[8].set_xlabel('Survived', fontsize=12)
axes[8].set_ylabel('Age', fontsize=12)
axes[8].set_xticks([0, 1])
axes[8].set_xticklabels(['Did not Survive', 'Survived'])

# Survival by Fare
sns.boxplot(data=df, x='Survived', y='Fare', ax=axes[9], hue='Survived', palette='crest', legend=False) # Explicitly set hue and hide legend
axes[9].set_title('Survival by Fare Distribution', fontsize=14)
axes[9].set_xlabel('Survived', fontsize=12)
axes[9].set_ylabel('Fare', fontsize=12)
axes[9].set_xticks([0, 1])
axes[9].set_xticklabels(['Did not Survive', 'Survived'])

# Survival by SibSp
sns.countplot(data=df, x='SibSp', hue='Survived', ax=axes[10], palette='viridis')
axes[10].set_title('Survival Count by Number of Siblings/Spouses', fontsize=14)
axes[10].set_xlabel('Number of Siblings/Spouses (SibSp)', fontsize=12)
axes[10].set_ylabel('Count', fontsize=12)
axes[10].legend(title='Survived', loc='upper right')

# Survival by Parch
sns.countplot(data=df, x='Parch', hue='Survived', ax=axes[11], palette='plasma')
axes[11].set_title('Survival Count by Number of Parents/Children', fontsize=14)
axes[11].set_xlabel('Number of Parents/Children (Parch)', fontsize=12)
axes[11].set_ylabel('Count', fontsize=12)
axes[11].legend(title='Survived', loc='upper right')


plt.tight_layout()
plt.show()

# %%
display(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Explore Feature Relationships
#
# ### Subtask:
# Visualize the relationships between numerical features using a pairplot and a correlation heatmap.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(18, 24))
axes = axes.flatten()

# Distribution of Age
sns.histplot(data=df, x='Age', ax=axes[0], kde=True, color='skyblue')
axes[0].set_title('Distribution of Passenger Age', fontsize=14)
axes[0].set_xlabel('Age', fontsize=12)
axes[0].set_ylabel('Frequency', fontsize=12)

# Distribution of Fare
sns.histplot(data=df, x='Fare', ax=axes[1], kde=True, color='lightcoral')
axes[1].set_title('Distribution of Passenger Fare', fontsize=14)
axes[1].set_xlabel('Fare', fontsize=12)
axes[1].set_ylabel('Frequency', fontsize=12)

# Distribution of Pclass
sns.countplot(data=df, x='Pclass', hue='Pclass', ax=axes[2], palette='viridis', legend=False) # Explicitly set hue and hide legend
axes[2].set_title('Distribution of Passenger Class', fontsize=14)
axes[2].set_xlabel('Passenger Class', fontsize=12)
axes[2].set_ylabel('Count', fontsize=12)

# Distribution of Sex
sns.countplot(data=df, x='Sex', hue='Sex', ax=axes[3], palette='plasma', legend=False) # Explicitly set hue and hide legend
axes[3].set_title('Distribution of Passenger Sex', fontsize=14)
axes[3].set_xlabel('Sex', fontsize=12)
axes[3].set_ylabel('Count', fontsize=12)

# Distribution of Embarked
sns.countplot(data=df.dropna(subset=['Embarked']), x='Embarked', hue='Embarked', ax=axes[4], palette='mako', legend=False) # Explicitly set hue and hide legend
axes[4].set_title('Distribution of Embarkation Point', fontsize=14)
axes[4].set_xlabel('Embarkation Point', fontsize=12)
axes[4].set_ylabel('Count', fontsize=12)

# Survival by Pclass
sns.countplot(data=df, x='Pclass', hue='Survived', ax=axes[5], palette='viridis')
axes[5].set_title('Survival Count by Passenger Class', fontsize=14)
axes[5].set_xlabel('Passenger Class', fontsize=12)
axes[5].set_ylabel('Count', fontsize=12)
axes[5].legend(title='Survived', loc='upper right')

# Survival by Sex
sns.countplot(data=df, x='Sex', hue='Survived', ax=axes[6], palette='plasma')
axes[6].set_title('Survival Count by Sex', fontsize=14)
axes[6].set_xlabel('Sex', fontsize=12)
axes[6].set_ylabel('Count', fontsize=12)
axes[6].legend(title='Survived', loc='upper right')

# Survival by Embarked
sns.countplot(data=df.dropna(subset=['Embarked']), x='Embarked', hue='Survived', ax=axes[7], palette='mako')
axes[7].set_title('Survival Count by Embarkation Point', fontsize=14)
axes[7].set_xlabel('Embarkation Point', fontsize=12)
axes[7].set_ylabel('Count', fontsize=12)
axes[7].legend(title='Survived', loc='upper right')

# Survival by Age
sns.violinplot(data=df.dropna(subset=['Age', 'Survived']), x='Survived', y='Age', ax=axes[8], hue='Survived', palette='rocket', legend=False) # Explicitly set hue and hide legend
axes[8].set_title('Survival by Age Distribution', fontsize=14)
axes[8].set_xlabel('Survived', fontsize=12)
axes[8].set_ylabel('Age', fontsize=12)
axes[8].set_xticks([0, 1])
axes[8].set_xticklabels(['Did not Survive', 'Survived'])

# Survival by Fare
sns.boxplot(data=df, x='Survived', y='Fare', ax=axes[9], hue='Survived', palette='crest', legend=False) # Explicitly set hue and hide legend
axes[9].set_title('Survival by Fare Distribution', fontsize=14)
axes[9].set_xlabel('Survived', fontsize=12)
axes[9].set_ylabel('Fare', fontsize=12)
axes[9].set_xticks([0, 1])
axes[9].set_xticklabels(['Did not Survive', 'Survived'])

# Survival by SibSp
sns.countplot(data=df, x='SibSp', hue='Survived', ax=axes[10], palette='viridis')
axes[10].set_title('Survival Count by Number of Siblings/Spouses', fontsize=14)
axes[10].set_xlabel('Number of Siblings/Spouses (SibSp)', fontsize=12)
axes[10].set_ylabel('Count', fontsize=12)
axes[10].legend(title='Survived', loc='upper right')

# Survival by Parch
sns.countplot(data=df, x='Parch', hue='Survived', ax=axes[11], palette='plasma')
axes[11].set_title('Survival Count by Number of Parents/Children', fontsize=14)
axes[11].set_xlabel('Number of Parents/Children (Parch)', fontsize=12)
axes[11].set_ylabel('Count', fontsize=12)
axes[11].legend(title='Survived', loc='upper right')


plt.tight_layout()
plt.show()

# %%
print("Interpreting the generated plots:")

print("\nDistribution of Age:")
print("The histogram shows a distribution of age that is somewhat right-skewed, with a peak around 20-30 years old. There is a tail extending towards older ages. The KDE line confirms this general shape. This suggests a majority of passengers were young adults.")

print("\nDistribution of Fare:")
print("The Fare distribution is highly right-skewed, with most fares being relatively low and a few outliers with very high fares. This indicates a wide range of economic backgrounds among passengers, with a concentration in lower fare classes.")

print("\nDistribution of Pclass:")
print("The count plot for Pclass shows that the majority of passengers were in Pclass 3, followed by Pclass 1, and then Pclass 2. This suggests that the ship had more third-class accommodations.")

print("\nDistribution of Sex:")
print("The count plot for Sex clearly shows that there were significantly more male passengers than female passengers.")

print("\nDistribution of Embarked:")
print("The count plot for Embarked indicates that most passengers embarked from 'S' (Southampton), followed by 'C' (Cherbourg), and then 'Q' (Queenstown).")

print("\nSurvival by Pclass:")
print("The stacked count plot shows a clear relationship between Pclass and survival. Passengers in Pclass 1 had a much higher survival rate than those in Pclass 2 or 3. Pclass 3 had the lowest survival rate.")

print("\nSurvival by Sex:")
print("The stacked count plot for Sex reveals a very strong relationship with survival. A significantly higher proportion of female passengers survived compared to male passengers. This is a very prominent pattern.")

print("\nSurvival by Embarked:")
print("The stacked count plot for Embarked shows some variation in survival rates by embarkation point, although the difference is less pronounced than for Pclass or Sex. Passengers from 'C' appear to have a slightly higher survival rate.")

print("\nSurvival by Age:")
print("The violin plot shows the distribution of age for those who survived and those who did not. The distribution for those who did not survive is slightly skewed towards younger adults, while the distribution for survivors is more spread out, including a notable number of children and older adults who survived.")

print("\nSurvival by Fare:")
print("The box plot for Survival by Fare indicates that passengers who paid higher fares had a higher chance of survival. The median fare for survivors is significantly higher than for those who did not survive, and there are many outliers with high fares in the survived group.")

print("\nSurvival by SibSp:")
print("The count plot for Survival by SibSp suggests that passengers with a small number of siblings or spouses (SibSp 1 or 2) had a higher survival rate than those with no siblings/spouses or a large number. Passengers with a large number of SibSp had a very low survival rate.")

print("\nSurvival by Parch:")
print("The count plot for Survival by Parch shows a similar pattern to SibSp. Passengers with a small number of parents or children (Parch 1, 2, or 3) had a higher survival rate than those with no parents/children or a large number.")
# Out:
# Interpreting the generated plots:
#
# Distribution of Age:
# The histogram shows a distribution of age that is somewhat right-skewed, with a peak around 20-30 years old. There is a tail extending towards older ages. The KDE line confirms this general shape. This suggests a majority of passengers were young adults.
#
# Distribution of Fare:
# The Fare distribution is highly right-skewed, with most fares being relatively low and a few outliers with very high fares. This indicates a wide range of economic backgrounds among passengers, with a concentration in lower fare classes.
#
# Distribution of Pclass:
# The count plot for Pclass shows that the majority of passengers were in Pclass 3, followed by Pclass 1, and then Pclass 2. This suggests that the ship had more third-class accommodations.
#
# Distribution of Sex:
# The count plot for Sex clearly shows that there were significantly more male passengers than female passengers.
#
# Distribution of Embarked:
# ...

# %% [markdown]
# ## Explore Feature Relationships
#
# ### Subtask:
# Visualize the relationships between numerical features using a pairplot and a correlation heatmap.

# %%
import matplotlib.pyplot as plt

categorical_cols = ['Pclass', 'Sex', 'Embarked']

for col in categorical_cols:
    if col in df.columns:
        plt.figure(figsize=(6, 6))
        df[col].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
        plt.title(f'Distribution of {col}')
        plt.ylabel('') # Hide the default y-label
        plt.show()
    else:
        print(f"Column '{col}' not found in the DataFrame.")
